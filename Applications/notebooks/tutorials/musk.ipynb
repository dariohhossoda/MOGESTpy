# %%
from mogestpy.quantity.Hydrological import Muskingum

# %%
import pandas as pd

# %%
df = pd.read_excel('Qjurumirim.xlsx')

# %%
df
# Out:
#        Qafl    Qnat
# 0    150.47  183.95
# 1    178.62  186.64
# 2    205.00  230.45
# 3    209.00  228.16
# 4    188.00  186.61
# ..      ...     ...
# 361  184.05  183.38
# 362  167.44  174.11
# 363  179.63  183.19
# 364  203.57  196.73
# 365  228.54  230.05
#
# [366 rows x 2 columns]

# %%
x = .25
K = 40/24
dt = 1

v1 = x <= dt/(2*K) <= 1-x
v2 = K/3 <= dt <= K

print(x, dt/(2*K), (1-x))
# Out:
# 0.25 0.3 0.75

# %%
musk = Muskingum.Muskingum.downstream_routing(df.Qnat.values, K, x, dt)

# %%
df['musk'] = musk

# %%
df[['musk', 'Qnat']].plot()
# Out:
# <Axes: >

# %%
df['dif'] = df['musk'] - df['Qnat']

# %%
df.dif
# Out:
# 0       0.000000
# 1      -2.241667
# 2     -36.881944
# 3      -4.238657
# 4      33.918557
#          ...
# 361    21.855970
# 362    11.367662
# 363    -5.672056
# 364   -12.228676
# 365   -29.804779
# Name: dif, Length: 366, dtype: float64

# %%
df.dif.sum()
# Out:
# -40.13904413119553

# %%
df.musk.sum()
# Out:
# 86520.3909558688

# %%
df.Qnat.sum()
# Out:
# 86560.53
